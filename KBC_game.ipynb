# %%
import random
import time

# %%
player=input("Enter Your Name =")
questions = [
    ["Ques1: What is the capital city of France?",
    "London" ,"Paris" ," Rome" ,"Berlin" , 'b' ],
    ["Ques2: What is the chemical symbol for water?",
      "02" ,"H20" ,"C02" ,"NaCl" , 'b'],
    ["Ques3: Which planet is known as the Red Planet?",
     "Mars", "jupiter", "venus", "saturn",'a'],
    ["Ques4: What is the largest mammal in the world?",
    "Arican elphant", "Giraffe","Blue Whale", "polar bear", 'c'],
    ["Ques5: What is the currency of Japan?",
      "euro", "pound", "dollar","yen", 'd'],
    ["Ques6: Who discovered penicillin?",
    "Alexander Flaming", "Marie CUrie", "Issac Newton", "Albert Einstein",'a'],
    ["Ques7: What is the chemical symbol for gold?",
    "Ag", "Fe", "Au", "Pb", 'c'],
    ["Ques8:Who wrote the famous play 'Romeo and Juliet'?",
    "Chetan Bhagat","Dilip Chitre","Kamala Das","William Shakespeare",'d'],
    ["Ques9:Who is the current Prime Minister of the United Kingdom (as of 2024)?",
    "Boris Johnson","Angela Merkel","Emmanuel Macron","Justin Trudeau",'a'],
    ["Ques10:Who is the author of the Harry Potter book series",
    "J.R.R. Tolkien","George R.R. Martin","J.K. Rowling"," Stephen King",'c']
]

levels= [1000,2000,3000,5000,10000,20000,40000,80000,160000,320000]

money = 0
lifelines = ["50-50", "Ask the Audience"]

def start_timer(sec):
    print("Time starts Now!!!")
    for remaining in range(sec, 0, -1):
        print(f"Time remaining: {remaining}sec", end='\r')
        time.sleep(1)
    print("\nTime's up!")

def choose_lifeline(lifelines, question):
    if len(lifelines) > 0:
        print("Available Lifelines:", lifelines)
        use_lifeline = input("Do you want to use a lifeline? (yes/no): ")
        if use_lifeline == "yes":
            print("1. 50-50")
            print("2. Ask the audience")
            lifeline_choice = int(input("Enter your choice (1/2): "))
            if lifeline_choice == 1 or lifeline_choice == 2:
                start_timer(10)  # Start timer for 10 seconds
            else:
                print("Invalid lifeline choice.")
            
            if lifeline_choice == 1:
                print("50-50 Lifeline:")
                options= ['a','b','c','d']
                correct_option = question[-1]
                options.remove(correct_option)
                
                incorrect_options = random.sample(options, 2)
                for option in incorrect_options:
                    print(f"Removed option: {option}")
                
            elif lifeline_choice == 2:
                print("Ask the Audience lifeline: Audience votes...")
                audience_votes = [random.randint(10, 60) for _ in range(4)]
                print("Audience votes:")
                for j in range(4):
                    print(f"option {j+1}: {audience_votes[j]}%")
    
    reply = input("Enter your answer (a-d) or 0 to QUIT:\n").lower()
    if reply == '0':
        money = levels[i-1]
        break
    elif (reply == question[-1]):
        print(f"Correct Ans!, YOU HAVE WON** Rs.{levels[i]}")
        money=levels[i]
    else:
        print("Wrong ans!!!")
        break

if (money>=20000 or money >= 320000):
    print(f"====={player.title()} this is your won amount: {money}=====")
# Out:
# Enter Your Name =shiv
#   Cell In[2], line 70
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
import random
import time

# %%
player=input("Enter Your Name =")
questions = [
    ["Ques1: What is the capital city of France?",
    "London" ,"Paris" ," Rome" ,"Berlin" , 'b' ],
    ["Ques2: What is the chemical symbol for water?",
      "02" ,"H20" ,"C02" ,"NaCl" , 'b'],
    ["Ques3: Which planet is known as the Red Planet?",
     "Mars", "jupiter", "venus", "saturn",'a'],
    ["Ques4: What is the largest mammal in the world?",
    "Arican elphant", "Giraffe","Blue Whale", "polar bear", 'c'],
    ["Ques5: What is the currency of Japan?",
      "euro", "pound", "dollar","yen", 'd'],
    ["Ques6: Who discovered penicillin?",
    "Alexander Flaming", "Marie CUrie", "Issac Newton", "Albert Einstein",'a'],
    ["Ques7: What is the chemical symbol for gold?",
    "Ag", "Fe", "Au", "Pb", 'c'],
    ["Ques8:Who wrote the famous play 'Romeo and Juliet'?",
    "Chetan Bhagat","Dilip Chitre","Kamala Das","William Shakespeare",'d'],
    ["Ques9:Who is the current Prime Minister of the United Kingdom (as of 2024)?",
    "Boris Johnson","Angela Merkel","Emmanuel Macron","Justin Trudeau",'a'],
    ["Ques10:Who is the author of the Harry Potter book series",
    "J.R.R. Tolkien","George R.R. Martin","J.K. Rowling"," Stephen King",'c']
]

lifelines = ["50-50", "Ask the Audience"]
levels = [1000, 2000, 3000, 5000, 10000, 20000, 40000, 80000, 160000, 320000]

def start_timer(sec):
    print("Time starts Now!!!")
    for remaining in range(sec, 0, -1):
        print(f"Time remaining: {remaining} sec", end='\r')
        time.sleep(1)
    print("\nTime's up!")   



for i in range(len(levels)):
    print(f"\nQuestion for Rs.{levels[i]}")
   
    question = f"Ques{i+1}: What is the capital city of France?"
    options = ['a. London', 'b. Paris', 'c. Rome', 'd. Berlin']
    correct_answer = 'b'

    print(question)
    for option in options:
        print(option)

    if len(lifelines) > 0:
        print("Available Lifelines:", lifelines)
        use_lifeline = input("Do you want to use a lifeline? (yes/no): ")
        if use_lifeline == "yes":
            print("1. 50-50")
            print("2. Ask the audience")
            lifeline_choice = int(input("Enter your choice (1/2):"))

            if lifeline_choice == 1:
                print("50-50 Lifeline:")
                options = ['a', 'b', 'c', 'd']
                options.remove(correct_answer)
                incorrect_options = random.sample(options, 2)
                for option in incorrect_options:
                    print(f"Removed option: {option}")
            elif lifeline_choice == 2:
                print("Ask the Audience lifeline: Audience votes...")
                audience_votes = [random.randint(10, 60) for i in range(4)]
                print("Audience votes:")
                for j in range(4):
                    print(f"option {j+1}: {audience_votes[j]}%")
               

    reply = input("Enter your answer (a-d) or 0 to QUIT:\n").lower()
            start_timer(10)
    if reply == '0':
        money = levels[i-1]
        break
    elif reply == correct_answer:
        print(f"Correct Ans!, YOU HAVE WON** Rs.{levels[i]}")
        money = levels[i]
    else:
        print("Wrong ans!!!")
        break

if (money >= 20000 or money >= 320000):
    print(f"====={player.title()} this is your won amount: {money}=====")
# Out:
#   Cell In[22], line 72
#     start_timer(10)
#     ^
# IndentationError: unexpected indent
